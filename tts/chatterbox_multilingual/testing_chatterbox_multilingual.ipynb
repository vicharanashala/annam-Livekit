# %%
# !git clone https://github.com/resemble-ai/chatterbox.git
# Out:
# Cloning into 'chatterbox'...
# remote: Enumerating objects: 267, done.
# remote: Total 267 (delta 0), reused 0 (delta 0), pack-reused 267 (from 1)
# Receiving objects: 100% (267/267), 1.49 MiB | 15.85 MiB/s, done.
# Resolving deltas: 100% (85/85), done.

# %%
# %cd chatterbox
# !ls
# Out:
# /content/chatterbox
# Chatterbox-Multilingual.png  example_vc.py	      multilingual_app.py
# Chatterbox-Turbo.jpg	     gradio_tts_app.py	      pyproject.toml
# example_for_mac.py	     gradio_tts_turbo_app.py  README.md
# example_tts.py		     gradio_vc_app.py	      src
# example_tts_turbo.py	     LICENSE

# %%
# !pip install -e .
# Out:
# Obtaining file:///content/chatterbox
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 61.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Getting requirements to build wheel ... error
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
# %cd chatterbox
# Out:
# /content/chatterbox

# %%
# %cd /content/chatterbox
# !ls
# Out:
# /content/chatterbox
# Chatterbox-Multilingual.png  example_vc.py	      multilingual_app.py
# Chatterbox-Turbo.jpg	     gradio_tts_app.py	      pyproject.toml
# example_for_mac.py	     gradio_tts_turbo_app.py  README.md
# example_tts.py		     gradio_vc_app.py	      src
# example_tts_turbo.py	     LICENSE

# %%
# !pip uninstall -y chatterbox-tts chatterbox
# !pip install -e .
# Out:
# WARNING: Skipping chatterbox-tts as it is not installed.
# WARNING: Skipping chatterbox as it is not installed.
# Obtaining file:///content/chatterbox
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Using cached numpy-1.25.2.tar.gz (10.8 MB)
#   Installing build dependencies ... done
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Getting requirements to build wheel ... error
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
# !pip uninstall -y chatterbox chatterbox-tts
# !pip install -e .
# Out:
# WARNING: Skipping chatterbox as it is not installed.
# WARNING: Skipping chatterbox-tts as it is not installed.
# Obtaining file:///content/chatterbox
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Using cached numpy-1.25.2.tar.gz (10.8 MB)
#   Installing build dependencies ... done
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Getting requirements to build wheel ... error
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
# %cd /content
# Out:
# /content

# %%
import torch
import torchaudio as ta
from chatterbox.mtl_tts import ChatterboxMultilingualTTS

device = "cuda" if torch.cuda.is_available() else "cpu"

model = ChatterboxMultilingualTTS.from_pretrained(device=device)

text = "नमस्ते, यह चैटरबॉक्स मॉडल है जो बहुत ही स्वाभाविक लगता है।"
wav = model.generate(text, language_id="hi")

ta.save("hindi.wav", wav, model.sr)
print("Saved hindi.wav")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-2855696976.py in <cell line: 0>()
#       1 import torch
#       2 import torchaudio as ta
# ----> 3 from chatterbox.mtl_tts import ChatterboxMultilingualTTS
#       4
#       5 device = "cuda" if torch.cuda.is_available() else "cpu"
#
# ModuleNotFoundError: No module named 'chatterbox.mtl_tts'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
