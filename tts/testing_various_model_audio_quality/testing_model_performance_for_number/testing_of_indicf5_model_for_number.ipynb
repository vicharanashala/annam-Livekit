# %%
# !pip install requests

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-c26e3c61-eeec-4be8-aec2-13052ae652f9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c26e3c61-eeec-4be8-aec2-13052ae652f9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import requests

def generate_tts_wav(text: str, ref_audio_path: str, ref_text: str, output_file: str = "upload_test.wav"):
    url = "https://mesne-unlicentiously-allie.ngrok-free.dev/tts_wav"

    # Form fields
    data = {
        "text": text,
        "ref_text": ref_text
    }

    # File field
    files = {
        "ref_audio_file": open(ref_audio_path, "rb")
    }

    try:
        response = requests.post(url, data=data, files=files)

        if response.status_code == 200:
            with open(output_file, "wb") as f:
                f.write(response.content)
            print(f"Audio saved as {output_file}")
        else:
            print("Request failed:", response.status_code)
            print(response.text)

    finally:
        files["ref_audio_file"].close()

# %% [markdown]
# **Testing to check bengali number pronunciation**

# %%
generate_tts_wav(
    text="২০২৬ সালে আমি নতুন লক্ষ্য ঠিক করলাম। এই বছর পরিশ্রম আর শেখার বছর হবে। স্বপ্ন পূরণের পথে আমি এগিয়ে চলব।",
    ref_audio_path="/content/bengali_reference_f.wav",
    ref_text="১৬ নম্বর বোস পাড়া লেন, উত্তর কলকাতার বাগবাজারের এই বাড়িটি তৈরি হয়েছিল আনুমানিক ১৮৪৫ সালের আশেপাশে।"
)
# Out:
# Audio saved as upload_test.wav

# %%
generate_tts_wav(
    text="আমি নতুন ১০ লক্ষ্য ঠিক করলাম। এই বছর পরিশ্রম আর শেখার বছর হবে। স্বপ্ন পূরণের পথে আমি এগিয়ে চলব।",
    ref_audio_path="/content/bengali_reference_f.wav",
    ref_text="১৬ নম্বর বোস পাড়া লেন, উত্তর কলকাতার বাগবাজারের এই বাড়িটি তৈরি হয়েছিল আনুমানিক ১৮৪৫ সালের আশেপাশে।"
)
# Out:
# Audio saved as upload_test.wav

# %%
generate_tts_wav(
    text="আমি নতুন ১০ লক্ষ্য ঠিক করলাম। এই বছর পরিশ্রম আর শেখার বছর হবে। স্বপ্ন পূরণের পথে আমি এগিয়ে চলব।",
    ref_audio_path="/content/bengali_reference_m.wav",
    ref_text="আমি কিভাবে সরকারি চিকিৎসা সেবা পেতে পারি? আপনি যদি শরণার্থী হন বা আপনার বসবাসের অনুমতি থাকে, তবে আপনি সরকারি স্বাস্থ্য পরিষেবা।"
)
# Out:
# Audio saved as upload_test.wav

# %%
generate_tts_wav(
    text="আমি প্রতিদিন সকাল ৬টায় উঠি এবং ২ কাপ চা খাই। আমার পরিবারের সদস্য সংখ্যা ৪ জন। আজ আমি ১০টি বই পড়ার লক্ষ্য নিয়েছি। গত মাসে আমি ৩টি পরীক্ষা দিয়েছিলাম এবং ১টিতে প্রথম স্থান পেয়েছি। আগামী ২০২6 সালে আমি আরও ভালো করার চেষ্টা করব।",
    ref_audio_path="/content/bengali_reference_m.wav",
    ref_text="আমি কিভাবে সরকারি চিকিৎসা সেবা পেতে পারি, আপনি যদি শরণার্থী হন বা আপনার বসবাসের অনুমতি থাকে, তবে আপনি সরকারি স্বাস্থ্য পরিষেবা।"
)
# Out:
# Audio saved as upload_test.wav

# %% [markdown]
# **Testing to check Hindi number pronunciation**

# %%
generate_tts_wav(
    text="मैं रोज़ सुबह 6 बजे उठता हूँ और 2 गिलास पानी पीता हूँ। मेरे परिवार में कुल 4 सदस्य हैं।",
    ref_audio_path="/content/Hindi_F_Tyagi.wav",
    ref_text="कृपया बिना टिकट यात्रा न करें, यह दंडनीय अपराध है।"
)
# Out:
# Audio saved as upload_test.wav

# %%
generate_tts_wav(
    text="आज सुबह मैं 5 किलोमीटर दौड़ा और 2 गिलास दूध पिया। मेरी कक्षा में कुल 30 छात्र हैं। कल हमने 7 विषयों की परीक्षा दी थी। इस महीने मैंने 12 नए शब्द सीखे हैं। आने वाले 2027 में मैं अपनी पढ़ाई में और बेहतर प्रदर्शन करना चाहता हूँ।",
    ref_audio_path="/content/Hindi_F_Deepika.wav",
    ref_text="आगरा के ताज महल में मुगल बादशाह शाहजहाँ के 360 में उर्स की शुरुआत की गई, जिसके चलते शाहजहाँ और मुमताज़ की कब्र का गेट खोला गया।"
)
# Out:
# Audio saved as upload_test.wav

# %% [markdown]
# **Testing to check Number pronunciation while writting number in word**

# %%
generate_tts_wav(
    text="मैं रोज़ सुबह छह बजे उठता हूँ और दो गिलास पानी पीता हूँ। मेरे परिवार में कुल चार सदस्य हैं। आज मैंने दस किताबें पढ़ने का लक्ष्य रखा है। पिछले महीने मैंने तीन परीक्षाएँ दी थीं और एक में प्रथम स्थान प्राप्त किया था। आने वाले वर्ष में मैं और अधिक मेहनत करूँगा।",
    ref_audio_path="/content/Hindi_F_Deepika.wav",
    ref_text="आगरा के ताज महल में मुगल बादशाह शाहजहाँ के 360 में उर्स की शुरुआत की गई, जिसके चलते शाहजहाँ और मुमताज़ की कब्र का गेट खोला गया।"
)
# Out:
# Audio saved as upload_test.wav

# %%
generate_tts_wav(
    text="मैं हर दिन पाँच बजे उठकर व्यायाम करता हूँ और दो किलोमीटर पैदल चलता हूँ। हमारे मोहल्ले में आठ दुकानें हैं। इस साल मैंने नौ नई किताबें खरीदी हैं और चार प्रतियोगिताओं में भाग लिया है। अगले महीने मैं तीन दोस्तों के साथ यात्रा पर जाने की योजना बना रहा हूँ।",
    ref_audio_path="/content/Hindi_F_Deepika.wav",
    ref_text="आगरा के ताज महल में मुगल बादशाह शाहजहाँ के 360 में उर्स की शुरुआत की गई, जिसके चलते शाहजहाँ और मुमताज़ की कब्र का गेट खोला गया।"
)
# Out:
# Audio saved as upload_test.wav
