# %%
# !pip install requests

# %%
import requests

url = "https://mesne-unlicentiously-allie.ngrok-free.dev/tts_wav"

payload = {
    "text": "আজ আমি একটি নতুন জিনিস শিখেছি।"
}

headers = {"Content-Type": "application/json"}

response = requests.post(url, json=payload, headers=headers)

with open("dynamic_test.wav", "wb") as f:
    f.write(response.content)

print("Saved dynamic_test.wav")

# %%
import requests

url = "https://mesne-unlicentiously-allie.ngrok-free.dev/tts_wav"

payload = {
    "text": "প্রযুক্তির সাহায্যে এখন আমরা সহজেই লেখা থেকে কথা বানাতে পারি।"
}

headers = {"Content-Type": "application/json"}

response = requests.post(url, json=payload, headers=headers)

with open("dynamic_test.wav", "wb") as f:
    f.write(response.content)

print("Saved dynamic_test.wav")
# Out:
# Saved dynamic_test.wav

# %%
import requests

url = "https://mesne-unlicentiously-allie.ngrok-free.dev/tts_wav"

payload = {
    "text": "आज मैं हिंदी भाषा में टेक्स्ट टू स्पीच का परीक्षण कर रहा हूँ।"
}

headers = {"Content-Type": "application/json"}

response = requests.post(url, json=payload, headers=headers)

with open("dynamic_test.wav", "wb") as f:
    f.write(response.content)

print("Saved dynamic_test.wav")
# Out:
# Saved dynamic_test.wav
