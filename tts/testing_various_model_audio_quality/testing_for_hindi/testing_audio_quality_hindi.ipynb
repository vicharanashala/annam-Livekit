# %%
# !pip install requests

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-64397e4a-7466-4a53-9b85-07ef8955e210" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-64397e4a-7466-4a53-9b85-07ef8955e210">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import requests

def generate_tts_wav(text: str, ref_audio_path: str, ref_text: str, output_file: str = "upload_test.wav"):
    url = "https://mesne-unlicentiously-allie.ngrok-free.dev/tts_wav"

    # Form fields
    data = {
        "text": text,
        "ref_text": ref_text
    }

    # File field
    files = {
        "ref_audio_file": open(ref_audio_path, "rb")
    }

    try:
        response = requests.post(url, data=data, files=files)

        if response.status_code == 200:
            with open(output_file, "wb") as f:
                f.write(response.content)
            print(f"Audio saved as {output_file}")
        else:
            print("Request failed:", response.status_code)
            print(response.text)

    finally:
        files["ref_audio_file"].close()

# %% [markdown]
# **Hindi Testing**

# %%
generate_tts_wav(
    text="किसान धरती का सच्चा सेवक होता है जो दिन-रात मेहनत करके अन्न उगाता है। उसकी मेहनत से ही देश का हर घर भोजन पाता है। धूप, बारिश और ठंड में भी वह खेतों में काम करता रहता है। किसान का जीवन त्याग और संघर्ष से भरा होता है। हमें हमेशा किसानों का सम्मान करना चाहिए क्योंकि वे हमारे जीवन का आधार हैं।",
    ref_audio_path="/content/Hindi_F_Deepika.wav",
    ref_text="आगरा के ताज महल में मुगल बादशाह शाहजहाँ के तीन सौ साठ में उर्स की शुरुआत की गई, जिसके चलते शाहजहाँ और मुमताज़ की कब्र का गेट खोला गया।"
)
# Out:
# Audio saved as upload_test.wav

# %%
generate_tts_wav(
    text="किसान हमारे देश की रीढ़ है। वह सुबह सूरज निकलने से पहले खेतों में काम करने लगता है। मिट्टी से उसका गहरा रिश्ता होता है। बीज बोकर वह भविष्य की उम्मीद उगाता है। धूप में पसीना बहाना उसकी दिनचर्या है। बारिश में भी वह अपने काम से पीछे नहीं हटता। ठंड में भी वह फसल की देखभाल करता है। उसकी मेहनत से हमें अन्न मिलता है। किसान का जीवन सरल लेकिन कठिन होता है। वह प्रकृति पर निर्भर रहता है। सूखा उसके लिए बड़ी चिंता बन जाता है। बाढ़ भी उसकी फसल नष्ट कर सकती है। फिर भी वह हार नहीं मानता। हर मौसम में नई शुरुआत करता है। उसका धैर्य हमें प्रेरणा देता है। उसका संघर्ष हमें जिम्मेदारी सिखाता है। समाज का हर वर्ग उस पर निर्भर है। बिना किसान के जीवन की कल्पना अधूरी है। हमें उसके अधिकारों की रक्षा करनी चाहिए। हमें हमेशा किसान का सम्मान करना चाहिए।",
    ref_audio_path="/content/Hindi_F_Deepika.wav",
    ref_text="आगरा के ताज महल में मुगल बादशाह शाहजहाँ के तीन सौ साठ में उर्स की शुरुआत की गई, जिसके चलते शाहजहाँ और मुमताज़ की कब्र का गेट खोला गया।"
)
# Out:
# Audio saved as upload_test.wav

# %%
generate_tts_wav(
    text="किसान हमारे देश की शान है। वह खेतों में मेहनत करके अन्न उगाता है। उसकी मेहनत से ही हमें भोजन मिलता है। धूप, बारिश और ठंड में भी वह काम करता रहता है। किसान का जीवन सरल लेकिन संघर्ष से भरा होता है। वह प्रकृति पर निर्भर रहता है। बीज बोकर वह भविष्य की उम्मीद जगाता है। उसका धैर्य हमें प्रेरणा देता है। हम सभी किसान पर निर्भर हैं। हमें हमेशा किसानों का सम्मान करना चाहिए।",
    ref_audio_path="/content/Hindi_F_Tyagi.wav",
    ref_text="कृपया बिना टिकट यात्रा न करें, यह दंडनीय अपराध है।"
)
# Out:
# Audio saved as upload_test.wav

# %%
generate_tts_wav(
    text="किसान हमारे देश की पहचान है। वह सुबह जल्दी उठकर खेतों में काम करता है। मिट्टी से उसका गहरा नाता होता है। बीज बोकर वह भविष्य की फसल तैयार करता है। धूप में पसीना बहाना उसकी आदत है। बारिश में भी वह अपने कर्तव्य से पीछे नहीं हटता। ठंड में भी फसलों की देखभाल करता है। उसकी मेहनत से हमें भोजन मिलता है। किसान का जीवन सरल लेकिन कठिन होता है। वह प्रकृति पर निर्भर रहता है। सूखा उसके लिए बड़ी चुनौती बन जाता है। बाढ़ उसकी फसल को नुकसान पहुँचा सकती है। फिर भी वह हार नहीं मानता। हर मौसम में नई शुरुआत करता है। उसका धैर्य हमें प्रेरणा देता है। उसका संघर्ष हमें मेहनत का मूल्य सिखाता है। समाज का हर वर्ग उस पर निर्भर है। बिना किसान के जीवन अधूरा है। हमें उसकी समस्याओं को समझना चाहिए। हमें हमेशा किसान का सम्मान करना चाहिए।",
    ref_audio_path="/content/Hindi_F_Tyagi.wav",
    ref_text="कृपया बिना टिकट यात्रा न करें, यह दंडनीय अपराध है।"
)
# Out:
# Audio saved as upload_test.wav

# %%
generate_tts_wav(
    text="जीवन हमें हर दिन कुछ नया सिखाता है। मेहनत से ही सफलता मिलती है। समय की कीमत समझना बहुत जरूरी है। अच्छे विचार अच्छे कर्मों को जन्म देते हैं। धैर्य से बड़ी से बड़ी समस्या हल हो जाती है। इंसान को कभी हार नहीं माननी चाहिए। प्रकृति हमें जीने का सहारा देती है।",
    ref_audio_path="/content/audio (1).mp3",
    ref_text="भारतीय किसान देश की अर्थव्यवस्था की मजबूत नींव है। वह खेतों में मेहनत करके पूरे राष्ट्र के लिए अन्न उगाता है। चाहे तपती धूप हो, मूसलाधार बारिश हो या कड़ाके की ठंड, किसान हर परिस्थिति में अपने काम पर डटा रहता है।"
)
# Out:
# Audio saved as upload_test.wav

# %%
generate_tts_wav(
    text="किसान धरती का सच्चा साथी है जो बीज बोकर जीवन उगाता है। उसकी मेहनत से ही हमारे घरों में भोजन पहुँचता है। मौसम की मार सहकर भी वह अपने काम में लगा रहता है। उसका जीवन संघर्ष और धैर्य की मिसाल है। हमें हमेशा किसान के योगदान का सम्मान करना चाहिए।",
    ref_audio_path="/content/audio (1).mp3",
    ref_text="भारतीय किसान देश की अर्थव्यवस्था की मजबूत नींव है। वह खेतों में मेहनत करके पूरे राष्ट्र के लिए अन्न उगाता है। चाहे तपती धूप हो, मूसलाधार बारिश हो या कड़ाके की ठंड, किसान हर परिस्थिति में अपने काम पर डटा रहता है।"
)
# Out:
# Audio saved as upload_test.wav
