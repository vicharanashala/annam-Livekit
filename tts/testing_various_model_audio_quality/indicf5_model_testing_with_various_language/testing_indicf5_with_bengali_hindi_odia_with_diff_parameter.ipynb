# %%
# !pip install requests

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-40bc2a05-beb5-4369-93c8-890de86df31c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-40bc2a05-beb5-4369-93c8-890de86df31c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import requests

def generate_tts_wav(text: str, ref_audio_path: str, ref_text: str, output_file: str = "upload_test.wav"):
    url = "https://mesne-unlicentiously-allie.ngrok-free.dev/tts_wav"

    # Form fields
    data = {
        "text": text,
        "ref_text": ref_text
    }

    # File field
    files = {
        "ref_audio_file": open(ref_audio_path, "rb")
    }

    try:
        response = requests.post(url, data=data, files=files)

        if response.status_code == 200:
            with open(output_file, "wb") as f:
                f.write(response.content)
            print(f"Audio saved as {output_file}")
        else:
            print("Request failed:", response.status_code)
            print(response.text)

    finally:
        files["ref_audio_file"].close()

# %%
generate_tts_wav(
    text="किसान दिन-रात मेहनत करता है और हमें भोजन देता है। हमें किसानों का सम्मान करना चाहिए।",
    ref_audio_path="/content/Record (online-voice-recorder.com).wav",
    ref_text="किसान हमारे देश के असली नायक हैं। उनकी मेहनत से ही हमें खाना मिलता है। वह सुबह से रात तक खेत में काम करता है। धूप, बारिश और ठंड में भी वह हार नहीं मानता। हमें किसानों का सम्मान करना चाहिए और उनकी मेहनत को समझना चाहिए।"
)
# Out:
# Audio saved as upload_test.wav

# %%
generate_tts_wav(
    text="किसान धरती से सोना उगाता है और हमारे लिए अन्न पैदा करता है। वह धूप और बारिश की परवाह किए बिना दिन-रात मेहनत करता है। उसकी मेहनत से खेतों में हरियाली आती है और हर घर तक भोजन पहुँचता है। इसलिए हमें किसानों के योगदान को कभी नहीं भूलना चाहिए।",
    ref_audio_path="/content/Record (online-voice-recorder.com).wav",
    ref_text="किसान हमारे देश के असली नायक हैं। उनकी मेहनत से ही हमें खाना मिलता है। वह सुबह से रात तक खेत में काम करता है। धूप, बारिश और ठंड में भी वह हार नहीं मानता। हमें किसानों का सम्मान करना चाहिए और उनकी मेहनत को समझना चाहिए।"
)
# Out:
# Audio saved as upload_test.wav

# %%
import requests

def generate_tts_wav(text: str, ref_audio_path: str, output_file: str = "upload_test.wav"):
    url = "https://mesne-unlicentiously-allie.ngrok-free.dev/tts_wav"

    # Only send the text (no ref_text)
    data = {
        "text": text
    }

    # Send only reference audio file
    files = {
        "ref_audio_file": open(ref_audio_path, "rb")
    }

    try:
        response = requests.post(url, data=data, files=files)

        if response.status_code == 200:
            with open(output_file, "wb") as f:
                f.write(response.content)
            print(f"Audio saved as {output_file}")
        else:
            print("Request failed:", response.status_code)
            print(response.text)

    finally:
        files["ref_audio_file"].close()


generate_tts_wav(
    text="କୃଷକ ଦେଶର ମୂଳ ଶକ୍ତି ଅଟେ।ତାଙ୍କର କଷ୍ଟରେ ଆମେ ଖାଦ୍ୟ ପାଉଛୁ।ସେମାନଙ୍କୁ ସମ୍ମାନ କରିବା ଆମର କର୍ତ୍ତବ୍ୟ।",
    ref_audio_path="/content/_Brilliant_Odia_Speech_odia_odiaspeech_odia_debate_viral_senior_debate_jnv_256KBPS.wav"
)
# Out:
# Audio saved as upload_test.wav

# %%
import requests

def generate_tts_wav(text: str, ref_audio_path: str, output_file: str = "upload_test.wav"):
    url = "https://mesne-unlicentiously-allie.ngrok-free.dev/tts_wav"

    # Only send the text (no ref_text)
    data = {
        "text": text
    }

    # Send only reference audio file
    files = {
        "ref_audio_file": open(ref_audio_path, "rb")
    }

    try:
        response = requests.post(url, data=data, files=files)

        if response.status_code == 200:
            with open(output_file, "wb") as f:
                f.write(response.content)
            print(f"Audio saved as {output_file}")
        else:
            print("Request failed:", response.status_code)
            print(response.text)

    finally:
        files["ref_audio_file"].close()


generate_tts_wav(
    text="କୃଷକ ଦେଶର ମୂଳ ଆଧାର ଅଟେ। ସେ ଦିନ-ରାତି କଷ୍ଟ କରି ଫସଲ ଚାଷ କରେ। ତାଙ୍କର ପରିଶ୍ରମରେ ଆମେ ଖାଦ୍ୟ ପାଉଛୁ। ଧୂପ ଓ ବର୍ଷାକୁ ସହି ସେ କାମ କରେ। ଖେତରେ ସବୁଜିମା ଆଣିବା ତାଙ୍କର ଲକ୍ଷ୍ୟ। ସମାଜର ଉନ୍ନତିରେ କୃଷକଙ୍କ ଅବଦାନ ଅମୂଲ୍ୟ। ଆମେ ସମସ୍ତେ କୃଷକଙ୍କୁ ସମ୍ମାନ କରିବା ଉଚିତ। ତାଙ୍କର ଜୀବନ ଅତ୍ୟନ୍ତ ସରଳ ଓ ସତ୍ୟବାଦୀ। କୃଷକ ନଥିଲେ ଆମ ଜୀବନ ଅସମ୍ଭବ। ସେମାନଙ୍କର ପରିଶ୍ରମକୁ କେବେ ଭୁଲିବା ଉଚିତ ନୁହେଁ।",
    ref_audio_path="/content/_Brilliant_Odia_Speech_odia_odiaspeech_odia_debate_viral_senior_debate_jnv_256KBPS.wav"
)
# Out:
# Audio saved as upload_test.wav

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-886074cf-351d-459e-968c-9bd14200cb30" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-886074cf-351d-459e-968c-9bd14200cb30">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import requests

def generate_tts_wav(text: str, ref_audio_path: str, ref_text: str, output_file: str = "upload_test.wav"):
    url = "https://mesne-unlicentiously-allie.ngrok-free.dev/tts_wav"

    # Form fields
    data = {
        "text": text,
        "ref_text": ref_text
    }

    # File field
    files = {
        "ref_audio_file": open(ref_audio_path, "rb")
    }

    try:
        response = requests.post(url, data=data, files=files)

        if response.status_code == 200:
            with open(output_file, "wb") as f:
                f.write(response.content)
            print(f"Audio saved as {output_file}")
        else:
            print("Request failed:", response.status_code)
            print(response.text)

    finally:
        files["ref_audio_file"].close()

# %%
generate_tts_wav(
    text="আজ সকালের সূর্যটা খুব সুন্দর ছিল, স্কুলে যাওয়ার পথে আমি নতুন বন্ধুদের সঙ্গে দেখা করলাম, আমরা সবাই মিলে পার্কে খেলাধুলা করলাম, দুপুরে মা রঙিন মাছের তরকারি বানালেন, বিকেলে বই পড়ার সময় আমি অনেক নতুন কিছু শিখলাম, সন্ধ্যায় বাবার সঙ্গে গল্প করলাম, রাতের খাবারে পরিবারের সবাই একসাথে খেয়েছিলাম, ঘুমোতে যাওয়ার আগে আমি আমার খেলার জিনিসগুলো সাজালাম, স্বপ্নে আমি একটি জাদুর দেশ ভ্রমণ করলাম, এবং সকালে আবার নতুন উদ্যম নিয়ে দিন শুরু করলাম।",
    ref_audio_path="/content/Record (online-voice-recorder.com) (2).wav",
    ref_text="সদগুরু শ্রী ১০৮ স্বামী নিগমানন্দ সরস্বতী পরমহংস দেব, যার বাল্যকালে নাম ছিল নলিনীকান্ত চট্টোপাধ্যায়।"
)
# Out:
# Audio saved as upload_test.wav

# %%
generate_tts_wav(
    text="একটি ছোট গ্রামে রাহুল নামে একটি ছেলে থাকত, সে প্রতিদিন সকালে নদীর পারে হাঁটতে যেত, একদিন সে নদীর তীরে একটি আহত পাখি দেখতে পেল, রাহুল পাখিটিকে সাবধানে তুলে বাড়িতে নিয়ে গেল, তার মা পাখিটিকে চিকিৎসা করার জন্য সাহায্য করলেন, কয়েকদিন পর পাখিটি আবার সুস্থ হয়ে উঠল, রাহুল ও পাখির মধ্যে গভীর বন্ধুত্ব গড়ে উঠল, প্রতি সকালে পাখি রাহুলের পাশে বসত এবং গান গাইত, গ্রামের লোকরাও রাহুলের এই ভালোবাসা দেখে অনুপ্রাণিত হল, শেষে পাখিটি আবার মুক্ত হয়ে আকাশে উড়ে গেল কিন্তু বন্ধুত্ব চিরকাল থাকল।",
    ref_audio_path="/content/Record (online-voice-recorder.com) (3).wav",
    ref_text="“আমার নাম ক্ষমা, ক্ষমা দাস, আমার বাবার নাম রাধাশ্যাম দাস, আমি তার ছোট মেয়ে থাকি কাঁথিতে।”"
)
# Out:
# Audio saved as upload_test.wav
