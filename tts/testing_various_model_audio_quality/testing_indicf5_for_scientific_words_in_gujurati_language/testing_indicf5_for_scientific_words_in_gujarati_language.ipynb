# %%
# !pip install requests

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f5e7e47e-1c5a-4add-b5d5-75bc5270e099" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f5e7e47e-1c5a-4add-b5d5-75bc5270e099">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # **Example 1**

# %%
import requests

def generate_tts_wav(text: str, ref_audio_path: str, ref_text: str, output_file: str = "upload_test.wav"):
    url = "https://mesne-unlicentiously-allie.ngrok-free.dev/tts_wav"

    # Form fields
    data = {
        "text": text,
        "ref_text": ref_text
    }

    # File field
    files = {
        "ref_audio_file": open(ref_audio_path, "rb")
    }

    try:
        response = requests.post(url, data=data, files=files)

        if response.status_code == 200:
            with open(output_file, "wb") as f:
                f.write(response.content)
            print(f"Audio saved as {output_file}")
        else:
            print("Request failed:", response.status_code)
            print(response.text)

    finally:
        files["ref_audio_file"].close()

# %%
generate_tts_wav(
    text = "લેબમાં p H value તપાસવામાં આવી અને તે F A Q રિપોર્ટમાં લખવામાં આવી।",
    ref_audio_path="/content/gujarati_audio.wav",
    ref_text="ખેડૂત આપણા દેશનો આધારસ્તંભ છે, જે પોતાની મહેનતથી સૌને અન્ન પૂરું પાડે છે."
)
# Out:
# Audio saved as upload_test.wav

# %% [markdown]
# # **Example 2**

# %%
generate_tts_wav(
    text = "આજે અમે FAQ અને Ph value વિશે ચર્ચા કરી.",
    ref_audio_path="/content/gujarati_audio.wav",
    ref_text="ખેડૂત આપણા દેશનો આધારસ્તંભ છે, જે પોતાની મહેનતથી સૌને અન્ન પૂરું પાડે છે."
)
# Out:
# Audio saved as upload_test.wav

# %% [markdown]
# # **Example 3**

# %%
generate_tts_wav(
    text = "આ API server આજે યોગ્ય રીતે કામ કરી રહ્યો છે.",
    ref_audio_path="/content/gujarati_audio.wav",
    ref_text="ખેડૂત આપણા દેશનો આધારસ્તંભ છે, જે પોતાની મહેનતથી સૌને અન્ન પૂરું પાડે છે."
)
# Out:
# Audio saved as upload_test.wav

# %% [markdown]
# # **Example 4(written "API server" from example 3 in gujarati language)**

# %%
generate_tts_wav(
    text = "આ એપીઆઈ સર્વર આજે યોગ્ય રીતે કામ કરી રહ્યો છે।",
    ref_audio_path="/content/gujarati_audio.wav",
    ref_text="ખેડૂત આપણા દેશનો આધારસ્તંભ છે, જે પોતાની મહેનતથી સૌને અન્ન પૂરું પાડે છે."
)
# Out:
# Audio saved as upload_test.wav
