# %%
# !pip install requests

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-1ff3fe23-b07f-401d-ad20-80b610ad66c3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1ff3fe23-b07f-401d-ad20-80b610ad66c3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os

os.listdir()
# Out:
# ['.config',
#  '8510465168518235277.wav',
#  '1017212797150914463.wav',
#  '10019901230699518471.wav',
#  '15185049990723743577.wav',
#  '10319899700709370082.wav',
#  '11750204283640661454.wav',
#  '14769714496548305027.wav',
#  '13366245730497613217.wav',
#  '10036619286088483.wav',
#  '14845585016580983957.wav',
#  'sample_data']

# %%
import requests
import os

url = "https://unoverwhelmed-martin-unintuitively.ngrok-free.dev/voice/v1/audio/transcriptions"

for file in os.listdir():

    if file.endswith(".wav"):

        with open(file, "rb") as f:

            files = {
                "file": (file, f, "audio/wav")
            }

            data = {
                "model": "whisper-1",
                "response_format": "json",
                "temperature": 0.0
            }

            response = requests.post(url, files=files, data=data)

        print("Audio File:", file)
        print("Status Code:", response.status_code)
        print("Response:", response.text)
        print("-----------------------------------")
# Out:
# Audio File: 8510465168518235277.wav
# Status Code: 200
# Response: {"text":"ਰੇਗਿਸਤਾਨ ਦੀ ਰੇਤ ਕਾਰਨ ਉੱਨੀ ਸੌ ਨੱਬੇ ਵਿੱਚ ਉਸ ਨੂੰ ਇਸ ਖ਼ਤਰਨਾਕ ਵਿਸ਼ਵ ਵਿਰਾਸਤ ਥਾਵਾਂ ਦੀ ਸੂਚੀ ਵਿੱਚ ਜੋੜਿਆ ਗਿਆ ਹੈ।"}
# -----------------------------------
# Audio File: 1017212797150914463.wav
# Status Code: 200
# Response: {"text":"ਇੱਕ ਪਰਮਾਣੂ ਬੰਬ ਇਸ ਸਿਧਾਂਤ 'ਤੇ ਕੰਮ ਕਰਦਾ ਹੈ ਕਿ ਇਹ ਕਈ ਪ੍ਰੋਟੋਨ ਅਤੇ ਨਿਊਟ੍ਰਾਨ ਨੂੰ ਇੱਕ ਕੇਂਦਰ ਬਿੰਦੂ ਵਿੱਚ ਇਕੱਠੇ ਰੱਖਣ ਲਈ ਊਰਜਾ ਲੈਂਦਾ ਹੈ."}
# -----------------------------------
# Audio File: 10019901230699518471.wav
# Status Code: 200
# Response: {"text":"ਅਲਹੀਦਾ ਕਰਨਾ ਅਤੇ ਮੁੜ ਸਮੇਲ ਕਰਨਾ ਹਰ ਇੱਕ ਪੀੜ੍ਹੀ ਦੇ ਦੋ ਪੁਲਾਂ ਵਿਚਕਾਰ ਪਰਿਵਰਤ ਰੂਪ ਨੂੰ ਅੱਗੇ ਪਿੱਛੇ ਪੂਰੀ ਤਰ੍ਹਾਂ ਬੇਅਦ ਤਰਤੀਬ ਕਰ ਦਿੰਦਾ ਹੈ."}
# -----------------------------------
# Audio File: 15185049990723743577.wav
# Status Code: 200
# Response: {"text":"ਇਹ ਪੋਸਟ ਸਤੰਬਰ ਦੋ ਹਜ਼ਾਰ ਸਤਰਾਂ ਵਿੱਚ ਪੂਰੀ ਤਰ੍ਹਾਂ ਚਾਲੂ ਹੋਣ ਵਾਲਾ ਹੈ, ਜਦੋਂ ਬ੍ਰਾਜ਼ੀਲ ਦੀਆਂ ਕਸਟਮਰ ਚੌਕੀਆਂ ਅੱਗੇ ਮੁਕੰਮਲ ਹੋਣ ਦੀ ਉਮੀਦ ਹੈ।"}
# -----------------------------------
# Audio File: 10319899700709370082.wav
# ...

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-12472abe-4e06-4c21-bfba-9bfb08596929" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-12472abe-4e06-4c21-bfba-9bfb08596929">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import requests
import os

url = "https://unoverwhelmed-martin-unintuitively.ngrok-free.dev/voice/v1/audio/transcriptions"

for file in os.listdir():

    if file.endswith(".wav"):

        with open(file, "rb") as f:

            files = {
                "file": (file, f, "audio/wav")
            }

            data = {
                "model": "whisper-1",
                "response_format": "json",
                "temperature": 0.0
            }

            response = requests.post(url, files=files, data=data)

        print("Audio File:", file)
        print("Status Code:", response.status_code)
        print("Response:", response.text)
        print("-----------------------------------")
# Out:
# Audio File: 8510465168518235277.wav
# Status Code: 200
# Response: {"text":"ਰੇਗਿਸਤਾਨ ਦੀ ਰੇਤ ਕਾਰਨ ਉੱਨੀ ਸੌ ਨੱਬੇ ਵਿੱਚ ਉਸ ਨੂੰ ਇਸ ਖ਼ਤਰਨਾਕ ਵਿਸ਼ਵ ਵਿਰਾਸਤ ਥਾਵਾਂ ਦੀ ਸੂਚੀ ਵਿੱਚ ਜੋੜਿਆ ਗਿਆ ਹੈ।"}
# -----------------------------------
# Audio File: 1017212797150914463.wav
# Status Code: 200
# Response: {"text":"ਇੱਕ ਪਰਮਾਣੂ ਬੰਬ ਇਸ ਸਿਧਾਂਤ 'ਤੇ ਕੰਮ ਕਰਦਾ ਹੈ ਕਿ ਇਹ ਕਈ ਪ੍ਰੋਟੋਨ ਅਤੇ ਨਿਊਟ੍ਰਾਨ ਨੂੰ ਇੱਕ ਕੇਂਦਰ ਬਿੰਦੂ ਵਿੱਚ ਇਕੱਠੇ ਰੱਖਣ ਲਈ ਊਰਜਾ ਲੈਂਦਾ ਹੈ."}
# -----------------------------------
# Audio File: 10019901230699518471.wav
# Status Code: 200
# Response: {"text":"ਅਲਹੀਦਾ ਕਰਨਾ ਅਤੇ ਮੁੜ ਸਮੇਲ ਕਰਨਾ ਹਰ ਇੱਕ ਪੀੜ੍ਹੀ ਦੇ ਦੋ ਪੁਲਾਂ ਵਿਚਕਾਰ ਪਰਿਵਰਤ ਰੂਪ ਨੂੰ ਅੱਗੇ ਪਿੱਛੇ ਪੂਰੀ ਤਰ੍ਹਾਂ ਬੇਅਦ ਤਰਤੀਬ ਕਰ ਦਿੰਦਾ ਹੈ."}
# -----------------------------------
# Audio File: 16770479107245302350.wav
# Status Code: 200
# Response: {"text":"ਬੱਕਰੀਆਂ ਨੂੰ ਪਹਿਲੀ ਵਾਰੀ ਆਰਾਮ ਦੀਆਂ ਜਾਗਰਸ਼ ਪਾਣੀਆਂ ਵਿੱਚ ਅੰਦਾਜ਼ਨ ਦਸ ਹਜ਼ਾਰ ਸਾਲ ਪਹਿਲਾਂ ਪਾਲਤੂ ਬਣਾਇਆ ਗਿਆ ਜਾਦਾ ਹੈ."}
# -----------------------------------
# Audio File: 12405557037689578954.wav
# Status Code: 200
# ...
